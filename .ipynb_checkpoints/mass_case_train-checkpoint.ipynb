# %%
import os
import pandas as pd
from matplotlib import pyplot as plt
from skimage import measure, morphology
import pydicom as dicom
import numpy as np
import cv2
import skimage.transform

#data path 수정
os.chdir("C:\\Users\\User\\Desktop\\G팔로미1\\G-팔로미 data")
os.getcwd()
# Out:
# 'C:\\Users\\User\\Desktop\\G팔로미1\\G-팔로미 data'

# %%
# Setting base path
#ROOT_PATH = os.path.join(os.getcwd(), 'Dataset_csv')
#CBISDDSM_csvPATH = os.path.join('CBISDDSM')
#MIAS_PATH = os.path.join(ROOT_PATH, 'MIAS')

# Load Dataframe from .csv
calc_train = pd.read_csv(("calc_case_description_train_set.csv"), index_col=0)
calc_test = pd.read_csv(("calc_case_description_test_set.csv"), index_col=0)
mass_train = pd.read_csv(("mass_case_description_train_set.csv"), index_col=0)
mass_test = pd.read_csv(("mass_case_description_test_set.csv"), index_col=0)

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

image=np.load('mass_train.npy',allow_pickle=True)
images=[]
for i in range(len(image)):
    try:
        #d=dicom.read_file(images_dir[i],force=True)
        #d = dicom.dcmread(images_dir[i])
        #image=d.pixel_array
        image_small = skimage.transform.resize(image[i], (224,224), preserve_range=True)
        images.append(image_small)
    except Exception:
        print(i)
        print("error")
# Out:
# Using TensorFlow backend.

# %%
X=np.stack(images)[...,None]
X=np.repeat(X,3,axis=-1)
#X=(X-np.mean(X))/np.std(X) #standardization
#X=(X-np.min(X))/(np.max(X)-np.min(X)) #normalization

#X = (0~65535), X.maen=47557.83, X_std=10686

# %%
from skimage import exposure
import numpy as np
def histogram_equalize(img):
    #img = rgb2gray(img)
    img_cdf, bin_centers = exposure.cumulative_distribution(img)
    return np.interp(img, bin_centers, img_cdf)

# %%
# from skimage.io import imshow

# X_hist=[]
# for i in range(len(X)):
#     img=histogram_equalize(X[i])
#     X_hist.append(img)

# %%
X_no_hist=histogram_equalize(X)

# %%
for i in range(30):
    plt.imshow(X_no_hist[i])
    plt.title(y[i])
    plt.show()

# %%
for i in range(30):
    plt.imshow(images[i],cmap='gray')
    plt.title(y[i])
    plt.show()

# %%
y=np.load('mass_train_label.npy')

# %%
# X_hist_without=[]
# y_without=[]

# for i in range(len(X_hist)):
#     if y[i]=='BENIGN_WITHOUT_CALLBACK':
#         continue
#     else:
#         X_hist_without.append(X_no_hist[i])
#         y_without.append(y[i])

# %%
len(X_no_hist)
len(y)
#len(X_hist_without)
#len(y_without)
# Out:
# 1316

# %%
# from sklearn.preprocessing import LabelEncoder

# encoder = LabelEncoder()
# encoder.fit(y_without)
# encoded_Y = encoder.transform(y_without)
# one_hot_y = np_utils.to_categorical(encoded_Y)

# y=encoded_Y #BENIGN, MALIGNANT순

# %%
np.save('mass_data_X_no_hist_with_callback.npy',X_no_hist)

# %%
np.save('mass_data_y_with_callback.npy',y)

# %%
for i in range(len(y)):
    if y[i] == 'MALIGNANT':
        y[i] = "mass_MALIGANT"
    else:
        y[i] = "mass_BENIGN"

# %%
np.unique(y,return_counts=True)
# Out:
# (array(['mass_BENIGN', 'mass_MALIGANT'], dtype='<U23'),
#  array([681, 635], dtype=int64))

# %%
len(X_no_hist)
#len(y)
# Out:
# 1316

# %%
# for i in range(len(y_without)):
#     if y_without[i] == 'MALIGNANT':
#         y_without[i] = "mass_MALIGANT"
#     else:
#         y_without[i] = "mass_BENIGN"

# %%
y_without
# Out:
# ['mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_BENIGN',
#  'mass_BENIGN',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  'mass_MALIGANT',
#  ...]
